# %% [markdown]
# <a href="https://colab.research.google.com/github/Klendale90/IDC4150/blob/main/final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install tweepy pandas

from google.colab import userdata
import tweepy
import pandas as pd

BEARER_TOKEN = userdata.get("X_BEARER_TOKEN")

client = tweepy.Client(
    bearer_token=BEARER_TOKEN
)

response = client.search_recent_tweets(
    query=(
        '"education system" (failure OR failing OR broken OR crisis) '
        'OR "TRIO program" '
        'OR "TRIO programs" '
        'OR TRIO jeopardy '
        'OR TRIO cuts '
        'OR TRIO defunding '
        '-is:retweet lang:en'
    ),
    max_results=10
)

print(len(response.data))

rows = []

for t in response.data:
    metrics = t.public_metrics or {}

    rows.append({
        "tweet_id": t.id,
        "text": t.text,
        "created_at": t.created_at,
        "likes": metrics.get("like_count", 0),
        "retweets": metrics.get("retweet_count", 0)
    })

import pandas as pd
df = pd.DataFrame(rows)
df.head()

df.head(10)

df.to_csv("education_trio_tweets.csv", index=False)

from google.colab import files
files.download("education_trio_tweets.csv")
# Out:
# ...
# 10
